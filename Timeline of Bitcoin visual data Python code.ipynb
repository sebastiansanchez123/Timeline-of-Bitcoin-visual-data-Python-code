# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
hash = pd.read_csv("hash-rate.csv")

# %%
hash
# Out:
#             date     hash_rate
# 0     2009-01-03  4.971027e-08
# 1     2009-01-06  0.000000e+00
# 2     2009-01-09  6.959438e-07
# 3     2009-01-12  4.424214e-06
# 4     2009-01-15  6.313204e-06
# ...          ...           ...
# 1356  2020-03-11  9.791919e+07
# 1357  2020-03-14  1.053248e+08
# 1358  2020-03-17  1.012106e+08
# 1359  2020-03-20  8.969068e+07
# 1360  2020-03-23  9.215924e+07
#
# [1361 rows x 2 columns]

# %%
hash.plot(x="date", y="hash_rate", figsize=(26,12))
plt.yscale("log")

# %%
hash.plot(x="date", y="hash_rate", figsize=(26,12))
